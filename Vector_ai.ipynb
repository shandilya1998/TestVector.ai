# %%
from google.colab import drive
drive.mount('/content/drive')
# !git clone https://github.com/shandilya1998/TestVector.ai
# Out:
# Mounted at /content/drive
# Cloning into 'TestVector.ai'...
# remote: Enumerating objects: 429, done.
# remote: Counting objects: 100% (429/429), done.
# remote: Compressing objects: 100% (264/264), done.
# remote: Total 429 (delta 164), reused 405 (delta 140), pack-reused 0
# Receiving objects: 100% (429/429), 113.83 MiB | 4.53 MiB/s, done.
# Resolving deltas: 100% (164/164), done.

# %%
import os
os.chdir('TestVector.ai/part1')

# %%
# !sh get_data.sh
# !python save_data.py
# Out:
# --2022-01-31 08:05:41--  http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz
# Resolving fashion-mnist.s3-website.eu-central-1.amazonaws.com (fashion-mnist.s3-website.eu-central-1.amazonaws.com)... 52.219.140.64
# Connecting to fashion-mnist.s3-website.eu-central-1.amazonaws.com (fashion-mnist.s3-website.eu-central-1.amazonaws.com)|52.219.140.64|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 26421880 (25M) [binary/octet-stream]
# Saving to: ‘data/train/train-images-idx3-ubyte.gz’
#
# data/train/train-im 100%[===================>]  25.20M   107MB/s    in 0.2s
#
# 2022-01-31 08:05:41 (107 MB/s) - ‘data/train/train-images-idx3-ubyte.gz’ saved [26421880/26421880]
#
# --2022-01-31 08:05:41--  http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz
# Resolving fashion-mnist.s3-website.eu-central-1.amazonaws.com (fashion-mnist.s3-website.eu-central-1.amazonaws.com)... 52.219.140.64
# ...

# %%
# !pip install torchmetrics
# !python run.py
# Out:
# ...
#      |████████████████████████████████| 396 kB 14.2 MB/s
# ...
# Epoch 0 done. Average Epoch Loss 1.83365349
# ----------------------------------------------
# Evaluation 0 done. Average Loss 1.78908861
# Accuracy 0.70929998 Precision 0.70851284 Recall 0.70929998 F1Score 0.68189311
# ----------------------------------------------
# Epoch 1 done. Average Epoch Loss 1.74106429
# Epoch 2 done. Average Epoch Loss 1.71458580
# Epoch 3 done. Average Epoch Loss 1.69949611
# Epoch 4 done. Average Epoch Loss 1.68773156
# Epoch 5 done. Average Epoch Loss 1.68091478
# ----------------------------------------------
# Evaluation 1 done. Average Loss 1.72576602
# Accuracy 0.74545002 Precision 0.74489284 Recall 0.74545002 F1Score 0.72518247
# ----------------------------------------------
# Epoch 6 done. Average Epoch Loss 1.67634754
# Epoch 7 done. Average Epoch Loss 1.67421396
# Epoch 8 done. Average Epoch Loss 1.67145636
# Epoch 9 done. Average Epoch Loss 1.67138315
# ...
